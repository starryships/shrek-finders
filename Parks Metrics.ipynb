# %% [markdown]
# # Metrics for Pittsburgh Parks

# %%
import pandas as pd

data = pd.read_csv("parks.csv", index_col="neighborhood")
data
# Out:
#                             id                     name        type  \
# neighborhood
# Beechview           2111959181           Able Long Park        Park
# Crawford-Roberts    1109513049  Albert Turk Graham Park        Park
# North Shore         1544096765               Alcoa Park        Park
# Allegheny Center    1212681573        Allegheny Commons        Park
# North Shore          954863286   Allegheny Landing Park        Park
# ...                        ...                      ...         ...
# Marshall-Shadeland  1460363095           Woods Run Park        Park
# Marshall-Shadeland   930068146         Young Field Park        Park
# Central Oakland     1127012019              Zulema Park        Park
# East Liberty        1719897212       Liberty Green Park        Park
# South Side Flats    1305573349         Esser Plaza Park  Open Space
#
#                    maintenance_responsibility  \
# neighborhood
# Beechview                    Parks - Southern
# ...

# %%
mr_data = data.groupby("maintenance_responsibility").count()
mr_data
# Out:
#                             id  name  type  image  council_district  ward  \
# maintenance_responsibility
# 1st Division                 1     1     1      0                 1     1
# 2nd Division                10    10    10      0                10    10
# 3rd Division                19    19    19      7                19    19
# 4th Division                 1     1     1      0                 1     1
# 5th Division                 3     3     3      0                 3     3
# 6th Division                 5     5     5      3                 5     5
# Parks - Eastern             22    22    22      7                22    22
# Parks - Northeast           25    25    25      5                25    25
# Parks - Northern            39    39    39     18                39    39
# Parks - Schenley            23    23    23     12                23    23
# Parks - Southern            29    29    29      4                29    29
# ...

# %%
nbr_data = data.groupby("neighborhood").count()
nbr_data
# Out:
#                      id  name  type  maintenance_responsibility  image  \
# neighborhood
# Allegheny Center      2     2     2                           2      0
# Allentown             2     2     2                           2      0
# Arlington             1     1     1                           1      0
# Banksville            2     2     2                           2      0
# Bedford Dwellings     1     1     1                           1      0
# ...                  ..   ...   ...                         ...    ...
# Upper Lawrenceville   3     3     3                           3      2
# West End              2     2     2                           2      0
# West Oakland          1     1     1                           1      0
# Westwood              3     3     3                           3      0
# Windgap               1     1     1                           1      0
#
#                      council_district  ward  tract  public_works_division  \
# neighborhood
# ...

# %%
mr_data.plot()
